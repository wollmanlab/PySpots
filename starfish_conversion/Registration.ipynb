# %%
from starfish import Codebook, DecodedIntensityTable, FieldOfView
from starfish.image import ApplyTransform, Filter, LearnTransform
from starfish.spots import DecodeSpots, FindSpots
from starfish.types import Axes, FunctionSource

# %%
from starfish import Experiment
import os
output_dir = '/hybedata/Images/Robert/TBI_v2/sham_m3_slide4_2019Nov04/spacetx/'
exp = Experiment.from_json(os.path.join(output_dir,'experiment.json'))

# %%
fov = exp.fov()
imgs = fov.get_image(FieldOfView.PRIMARY_IMAGES)
dots = fov.get_image("dots")
nuclei = fov.get_image("nuclei")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-17de14ae42d8> in <module>
#       1 fov = exp.fov()
# ----> 2 imgs = fov.get_image(FieldOfView.PRIMARY_IMAGES)
#       3 dots = fov.get_image("dots")
#       4 nuclei = fov.get_image("nuclei")
#
# ~/PythonRepos/starfish/starfish/core/experiment/experiment.py in get_image(self, item, aligned_group, rounds, chs, zplanes, x, y)
#     145         stack_iterator = self.get_images(item=item, rounds=rounds,
#     146                                          chs=chs, zplanes=zplanes, x=x, y=y)
# --> 147         return next(stack_iterator)
#     148
#     149     def get_images(self, item: str,
#
# ~/PythonRepos/starfish/starfish/core/experiment/experiment.py in __next__(self)
#     207     def __next__(self) -> ImageStack:
#     208         aligned_group = next(self.aligned_groups)
# --> 209         stack = ImageStack.from_tileset(self.tileset, aligned_group)
#     210         return stack
#     211
#
# ~/PythonRepos/starfish/starfish/core/imagestack/imagestack.py in from_tileset(cls, tileset, crop_parameters)
#     271         if crop_parameters is not None:
#     272             tile_data = CroppedTileCollectionData(tile_data, crop_parameters)
# --> 273         return ImageStack.from_tile_collection_data(tile_data)
#     274
#     275     @classmethod
#
# ~/PythonRepos/starfish/starfish/core/imagestack/imagestack.py in from_tile_collection_data(cls, tile_data)
#     165             if not (
#     166                     np.array_equal(
# --> 167                         first_tile.coordinates[Coordinates.X], tile.coordinates[Coordinates.X])
#     168                     and np.array_equal(
#     169                         first_tile.coordinates[Coordinates.Y], tile.coordinates[Coordinates.Y])
#
# ~/PythonRepos/starfish/starfish/core/imagestack/parser/crop.py in coordinates(self)
#     258     @property
#     259     def coordinates(self) -> Mapping[Coordinates, ArrayLike[Number]]:
# --> 260         return self.cropping_parameters.crop_coordinates(self.backing_tile_data.coordinates)
#     261
#     262     @property
#
# ~/PythonRepos/starfish/starfish/core/imagestack/parser/tileset/_parser.py in coordinates(self)
#      56         yrange = self._wrapped_tile.coordinates[Coordinates.Y]
#      57         return_coords = {
# ---> 58             Coordinates.X: np.linspace(xrange[0], xrange[1], self.tile_shape[Axes.X]),
#      59             Coordinates.Y: np.linspace(yrange[0], yrange[1], self.tile_shape[Axes.Y]),
#      60         }
#
# ~/PythonRepos/starfish/starfish/core/imagestack/parser/tileset/_parser.py in tile_shape(self)
#      40     @property
#      41     def tile_shape(self) -> Mapping[Axes, int]:
# ---> 42         self._load()
#      43         raw_tile_shape = self._numpy_array.shape
#      44         assert len(raw_tile_shape) == 2
#
# ~/PythonRepos/starfish/starfish/core/imagestack/parser/tileset/_parser.py in _load(self)
#      36         if self._numpy_array is not None:
#      37             return
# ---> 38         self._numpy_array = self._wrapped_tile.numpy_array
#      39
#      40     @property
#
# ~/PythonRepos/slicedimage/slicedimage/_tile.py in numpy_array(self)
#      45             return self._numpy_array
#      46         else:
# ---> 47             result = self._numpy_array_future()
#      48
#      49             if self._tile_shape is not None:
#
# ~/PythonRepos/slicedimage/slicedimage/io/_v0_1_0.py in __call__(self, *args, **kwargs)
#     167     def __call__(self, *args, **kwargs):
#     168         with self.source_fh_contextmanager as fh:
# --> 169             return self.tile_format.reader_func(fh)
#
# ~/PythonRepos/slicedimage/slicedimage/_formats.py in reader(f)
#       6
#       7     def reader(f):
# ----> 8         return volread(f, format="tiff")
#       9
#      10     return reader
#
# ~/miniconda3/envs/starfish/lib/python3.7/site-packages/imageio/core/functions.py in volread(uri, format, **kwargs)
#     453     reader = read(uri, format, "v", **kwargs)
#     454     with reader:
# --> 455         return reader.get_data(0)
#     456
#     457
#
# ~/miniconda3/envs/starfish/lib/python3.7/site-packages/imageio/core/format.py in get_data(self, index, **kwargs)
#     344             self._BaseReaderWriter_last_index = index
#     345             try:
# --> 346                 im, meta = self._get_data(index, **kwargs)
#     347             except StopIteration:
#     348                 raise IndexError(index)
#
# ~/miniconda3/envs/starfish/lib/python3.7/site-packages/imageio/plugins/tifffile.py in _get_data(self, index)
#     245                 if index != 0:
#     246                     raise IndexError('Tiff support no more than 1 "volume" per file')
# --> 247                 im = self._tf.asarray()  # request as singleton image
#     248                 meta = self._meta
#     249             else:
#
# ~/miniconda3/envs/starfish/lib/python3.7/site-packages/imageio/plugins/_tifffile.py in asarray(self, key, series, out, validate, maxworkers)
#    1900                     typecode, product(series.shape), out=out, native=True)
#    1901         elif len(pages) == 1:
# -> 1902             result = pages[0].asarray(out=out, validate=validate)
#    1903         else:
#    1904             result = stack_pages(pages, out=out, maxworkers=maxworkers)
#
# ~/miniconda3/envs/starfish/lib/python3.7/site-packages/imageio/plugins/_tifffile.py in asarray(self, out, squeeze, lock, reopen, maxsize, validate)
#    3536                     if lsb2msb:
#    3537                         strip = reverse_bitorder(strip)
# -> 3538                     strip = decompress(strip)
#    3539                     strip = unpack(strip)
#    3540                     size = min(result.size, strip.size, strip_size,
#
# ~/miniconda3/envs/starfish/lib/python3.7/site-packages/imageio/plugins/_tifffile.py in decode_packbits(encoded)
#    8295             i += 1
#    8296             if n < 129:
# -> 8297                 result_extend(encoded[i:i+n])
#    8298                 i += n
#    8299             elif n > 129:
#
# KeyboardInterrupt:

# %%
fov = exp.fov()
imgs = fov.get_image("primary",zplanes=[1],chs=[1])
dots = fov.get_image("dots",zplanes=[0],rounds=[0])
nuclei = fov.get_image("nuclei",zplanes=[1])

# %%
learn_translation = LearnTransform.Translation(reference_stack=dots, axes=Axes.ROUND, upsampling=1000)

# %%
transforms_list = learn_translation.run(fov.get_image("dots",zplanes=[0]))
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
# 100%|██████████| 9/9 [00:02<00:00,  3.51it/s]

# %%
transforms_list
# Out:
# tile indices: {<Axes.ROUND: 'r'>: 0}
# translation: y=0.0, x=0.0, rotation: 0.0, scale: 1.0
# tile indices: {<Axes.ROUND: 'r'>: 1}
# translation: y=-0.002, x=0.0, rotation: 0.0, scale: 1.0
# tile indices: {<Axes.ROUND: 'r'>: 2}
# translation: y=0.004, x=-0.008, rotation: 0.0, scale: 1.0
# tile indices: {<Axes.ROUND: 'r'>: 3}
# translation: y=-0.003, x=-0.003, rotation: 0.0, scale: 1.0
# tile indices: {<Axes.ROUND: 'r'>: 4}
# translation: y=0.002, x=0.002, rotation: 0.0, scale: 1.0
# tile indices: {<Axes.ROUND: 'r'>: 5}
# translation: y=0.002, x=0.003, rotation: 0.0, scale: 1.0
# tile indices: {<Axes.ROUND: 'r'>: 6}
# translation: y=-0.001, x=-0.001, rotation: 0.0, scale: 1.0
# tile indices: {<Axes.ROUND: 'r'>: 7}
# translation: y=-0.009, x=0.005, rotation: 0.0, scale: 1.0
# tile indices: {<Axes.ROUND: 'r'>: 8}
# translation: y=0.001, x=-0.001, rotation: 0.0, scale: 1.0

# %%
warp = ApplyTransform.Warp()
registered_imgs = warp.run(imgs, transforms_list=transforms_list, verbose=True)
# Out:
# 100%|██████████| 9/9 [00:02<00:00,  3.20it/s]

# %%
imgs.xarray
# Out:
# 100%|██████████| 9/9 [00:02<00:00,  3.28it/s]
# <xarray.DataArray (r: 9, c: 1, z: 1, y: 2048, x: 2048)>
# array([[[[[0.00401312, 0.00448615, 0.00444038, ..., 0.01222248,
#            0.01223774, 0.01087968],
#           [0.00444038, 0.00480659, 0.00448615, ..., 0.01211566,
#            0.01242084, 0.01139849],
#           [0.00433356, 0.00418097, 0.00418097, ..., 0.01293965,
#            0.01173419, 0.01213092],
#           ...,
#           [0.01878386, 0.02075227, 0.02140841, ..., 0.00444038,
#            0.00355535, 0.0041352 ],
#           [0.01899748, 0.0205539 , 0.02001984, ..., 0.00358587,
#            0.00392157, 0.00376898],
#           [0.01918059, 0.01982147, 0.02253758, ..., 0.00381476,
#            0.00393683, 0.00299077]]]],
#
#
#
#        [[[[0.00285344, 0.00343328, 0.00317388, ..., 0.00424201,
#            0.00415045, 0.00392157],
#           [0.00384527, 0.00341802, 0.00300603, ..., 0.00469978,
#            0.00482185, 0.00483711],
#           [0.00335698, 0.0040589 , 0.00335698, ..., 0.00457771,
#            0.00469978, 0.00482185],
#           ...,
#           [0.0071107 , 0.0065919 , 0.00679026, ..., 0.00387579,
#            0.00311284, 0.0030518 ],
#           [0.00578317, 0.00581369, 0.00660716, ..., 0.0031281 ,
#            0.00317388, 0.00352483],
#           [0.00613413, 0.00630198, 0.00619516, ..., 0.00317388,
#            0.00317388, 0.00328069]]]],
#
#
#
#        [[[[0.00404364, 0.00315862, 0.00320439, ..., 0.00434882,
#            0.00463874, 0.00434882],
#           [0.00334173, 0.00325017, 0.00320439, ..., 0.0047303 ,
#            0.0043946 , 0.00479133],
#           [0.0034638 , 0.0033875 , 0.00318914, ..., 0.00485237,
#            0.00444038, 0.00421149],
#           ...,
#           [0.00663767, 0.00605783, 0.00581369, ..., 0.00318914,
#            0.00251774, 0.0031281 ],
#           [0.00556954, 0.00569161, 0.00534066, ..., 0.00323491,
#            0.00291447, 0.00323491],
#           [0.00544747, 0.00622568, 0.00663767, ..., 0.0031281 ,
#            0.00328069, 0.00228885]]]],
#
#
#
#        ...,
#
#
#
#        [[[[0.00280766, 0.00344854, 0.00265507, ..., 0.00361639,
#            0.00343328, 0.00317388],
#           [0.00292973, 0.00314336, 0.00288396, ..., 0.00291447,
#            0.00396735, 0.0031281 ],
#           [0.00294499, 0.0031281 , 0.0030518 , ..., 0.0039826 ,
#            0.00332647, 0.00425727],
#           ...,
#           [0.00440986, 0.00328069, 0.00360113, ..., 0.002533  ,
#            0.00323491, 0.00268559],
#           [0.00303655, 0.00340276, 0.00337224, ..., 0.00317388,
#            0.00334173, 0.0037232 ],
#           [0.00418097, 0.00341802, 0.0037232 , ..., 0.00369268,
#            0.00296025, 0.00280766]]]],
#
#
#
#        [[[[0.00357061, 0.00285344, 0.00343328, ..., 0.00387579,
#            0.0040589 , 0.0041352 ],
#           [0.00358587, 0.00357061, 0.00347906, ..., 0.00402838,
#            0.00445563, 0.00387579],
#           [0.00347906, 0.00369268, 0.00376898, ..., 0.00422675,
#            0.00471504, 0.00436408],
#           ...,
#           [0.00523384, 0.00514229, 0.00555428, ..., 0.00300603,
#            0.00329595, 0.00328069],
#           [0.00642405, 0.00495918, 0.00578317, ..., 0.0030518 ,
#            0.00325017, 0.00347906],
#           [0.00486763, 0.00469978, 0.00541695, ..., 0.00321965,
#            0.0030518 , 0.00262455]]]],
#
#
#
#        [[[[0.00306706, 0.00363165, 0.00354009, ..., 0.00430304,
#            0.00383001, 0.00451667],
#           [0.00370794, 0.00384527, 0.00361639, ..., 0.00469978,
#            0.00448615, 0.00474556],
#           [0.00424201, 0.00402838, 0.00401312, ..., 0.00459297,
#            0.00433356, 0.00459297],
#           ...,
#           [0.00679026, 0.00683604, 0.00733959, ..., 0.00337224,
#            0.00325017, 0.00334173],
#           [0.00712596, 0.00708019, 0.00753796, ..., 0.00357061,
#            0.00373846, 0.00335698],
#           [0.00534066, 0.0062562 , 0.00679026, ..., 0.00343328,
#            0.00341802, 0.0039826 ]]]]], dtype=float32)
# Coordinates:
#   * r        (r) int64 0 1 2 3 4 5 6 7 8
#   * c        (c) int64 1
#   * z        (z) int64 1
#     xc       (x) float64 2.411e+03 2.411e+03 2.411e+03 ... 2.624e+03 2.624e+03
#     yc       (y) float64 -3.087e+03 -3.087e+03 ... -2.874e+03 -2.874e+03
#     zc       (z) float64 3.093e+03
# Dimensions without coordinates: y, x

# %%
registered_imgs.xarray
# Out:
# <xarray.DataArray (r: 9, c: 1, z: 1, y: 2048, x: 2048)>
# array([[[[[0.00401312, 0.00448615, 0.00444038, ..., 0.01222248,
#            0.01223774, 0.01087968],
#           [0.00444038, 0.00480659, 0.00448615, ..., 0.01211566,
#            0.01242084, 0.01139849],
#           [0.00433356, 0.00418097, 0.00418097, ..., 0.01293965,
#            0.01173419, 0.01213092],
#           ...,
#           [0.01878386, 0.02075227, 0.02140841, ..., 0.00444038,
#            0.00355535, 0.0041352 ],
#           [0.01899748, 0.0205539 , 0.02001984, ..., 0.00358587,
#            0.00392157, 0.00376898],
#           [0.01918059, 0.01982147, 0.02253758, ..., 0.00381476,
#            0.00393683, 0.00299077]]]],
#
#
#
#        [[[[0.00284773, 0.00343212, 0.0031744 , ..., 0.0042436 ,
#            0.00415064, 0.00392203],
#           [0.00383758, 0.00341888, 0.00300685, ..., 0.00469859,
#            0.00482161, 0.00483708],
#           [0.00335027, 0.0040575 , 0.00335839, ..., 0.00457682,
#            0.00469953, 0.00482161],
#           ...,
#           [0.00709648, 0.00659293, 0.00678987, ..., 0.00387524,
#            0.00311437, 0.00305193],
#           [0.0057716 , 0.00581363, 0.00660557, ..., 0.00312822,
#            0.00317379, 0.00352413],
#           [0.00612186, 0.00630164, 0.00619538, ..., 0.00317348,
#            0.00317388, 0.00328048]]]],
#
#
#
#        [[[[0.00400778, 0.00313353, 0.00317949, ..., 0.00431518,
#            0.00460048, 0.00429677],
#           [0.00334695, 0.00324926, 0.00320361, ..., 0.00472592,
#            0.00439812, 0.00476864],
#           [0.00346252, 0.00338562, 0.00319046, ..., 0.00484975,
#            0.00443911, 0.00419926],
#           ...,
#           [0.00662975, 0.00605458, 0.00582517, ..., 0.0031855 ,
#            0.00252661, 0.00311328],
#           [0.00557855, 0.00569314, 0.00534901, ..., 0.00323325,
#            0.00291259, 0.00322112],
#           [0.00545154, 0.00622303, 0.00662661, ..., 0.00312955,
#            0.00327383, 0.00228724]]]],
#
#
#
#        ...,
#
#
#
#        [[[[0.00280205, 0.00344445, 0.00265321, ..., 0.00361247,
#            0.00343003, 0.00317096],
#           [0.00292668, 0.00314345, 0.00288399, ..., 0.00291568,
#            0.00396576, 0.00312898],
#           [0.00294203, 0.00312793, 0.00305171, ..., 0.00398126,
#            0.00332776, 0.00425521],
#           ...,
#           [0.00440461, 0.00328202, 0.0036007 , ..., 0.00253382,
#            0.00323432, 0.00268688],
#           [0.00303488, 0.00340228, 0.0033725 , ..., 0.00317337,
#            0.00334145, 0.00372178],
#           [0.00417565, 0.00341877, 0.00372255, ..., 0.00369117,
#            0.00296136, 0.00280873]]]],
#
#
#
#        [[[[0.00353855, 0.00286345, 0.00342832, ..., 0.00388178,
#            0.00405922, 0.00413324],
#           [0.00355307, 0.00357135, 0.00348132, ..., 0.00403553,
#            0.00445308, 0.00388344],
#           [0.00344669, 0.00369037, 0.00376632, ..., 0.0042286 ,
#            0.00470921, 0.004367  ],
#           ...,
#           [0.00519264, 0.00514226, 0.0055517 , ..., 0.00300885,
#            0.00329311, 0.00328181],
#           [0.00635852, 0.00497101, 0.00577393, ..., 0.00305293,
#            0.00324741, 0.00347275],
#           [0.0047997 , 0.00467778, 0.00538345, ..., 0.00320629,
#            0.00303805, 0.00261526]]]],
#
#
#
#        [[[[0.00306456, 0.00362792, 0.00353655, ..., 0.00429827,
#            0.00382687, 0.00450764],
#           [0.00370744, 0.00384483, 0.00361681, ..., 0.00469917,
#            0.00448576, 0.00474058],
#           [0.00424126, 0.00402818, 0.00401305, ..., 0.00459281,
#            0.00433397, 0.00458852],
#           ...,
#           [0.00679135, 0.00683633, 0.0073387 , ..., 0.00337191,
#            0.00325011, 0.00333803],
#           [0.00712558, 0.0070804 , 0.00753709, ..., 0.00357058,
#            0.00373759, 0.00335361],
#           [0.00534336, 0.00625756, 0.00679095, ..., 0.0034334 ,
#            0.0034189 , 0.003978  ]]]]], dtype=float32)
# Coordinates:
#   * r        (r) int64 0 1 2 3 4 5 6 7 8
#   * c        (c) int64 1
#   * z        (z) int64 1
#     xc       (x) float64 2.411e+03 2.411e+03 2.411e+03 ... 2.624e+03 2.624e+03
#     yc       (y) float64 -3.087e+03 -3.087e+03 ... -2.874e+03 -2.874e+03
#     zc       (z) float64 3.093e+03
# Dimensions without coordinates: y, x

# %%
def process_fov(fov: FieldOfView, codebook: Codebook) -> DecodedIntensityTable:
    """Process a single field of view of ISS data
    Parameters
    ----------
    fov : FieldOfView
        the field of view to process
    codebook : Codebook
        the Codebook to use for decoding

    Returns
    -------
    DecodedSpots :
        tabular object containing the locations of detected spots.
    """

    # note the structure of the 5D tensor containing the raw imaging data
    imgs = fov.get_image(FieldOfView.PRIMARY_IMAGES)
    dots = fov.get_image("dots")
    nuclei = fov.get_image("nuclei")

    print("Learning Transform")
    learn_translation = LearnTransform.Translation(reference_stack=dots, axes=Axes.ROUND, upsampling=1000)
    transforms_list = learn_translation.run(imgs.reduce({Axes.CH, Axes.ZPLANE}, func="max"))

    print("Applying transform")
    warp = ApplyTransform.Warp()
    registered_imgs = warp.run(imgs, transforms_list=transforms_list, verbose=True)

    print("Filter WhiteTophat")
    filt = Filter.WhiteTophat(masking_radius=15, is_volume=False)

    filtered_imgs = filt.run(registered_imgs, verbose=True)
    filt.run(dots, verbose=True, in_place=True)
    filt.run(nuclei, verbose=True, in_place=True)

    print("Detecting")
    detector = FindSpots.BlobDetector(
        min_sigma=1,
        max_sigma=10,
        num_sigma=30,
        threshold=0.01,
        measurement_type='mean',
    )
    dots_max = dots.reduce((Axes.ROUND, Axes.ZPLANE), func="max", module=FunctionSource.np)
    spots = detector.run(image_stack=filtered_imgs, reference_image=dots_max)

    print("Decoding")
    decoder = DecodeSpots.PerRoundMaxChannel(codebook=codebook)
    decoded = decoder.run(spots=spots)
    return decoded
